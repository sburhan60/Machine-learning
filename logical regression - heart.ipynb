# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
data = pd.read_csv(r"C:\Users\user\Desktop\Data science Master\heart.csv")

# %%
data.shape
# Out:
# (918, 12)

# %%
data.head(5)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
data.tail(5)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0

# %%
print (data.isnull().values.any())
# Out:
# False

# %%
data.corr()
# Out:
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.107589
# Cholesterol      -0.232741
# FastingBS         0.267291
# MaxHR            -0.400421
# Oldpeak           0.403951
# HeartDisease      1.000000

# %%
data["HeartDisease"].value_counts()*100/len(data)
# Out:
# 1    55.337691
# 0    44.662309
# Name: HeartDisease, dtype: float64

# %%
data.HeartDisease.value_counts()
# Out:
# 1    508
# 0    410
# Name: HeartDisease, dtype: int64

# %%
data["Age"].hist(edgecolor = "black")
# Out:
# <AxesSubplot:>

# %%
sns.countplot(data['Cholesterol'])
plt.show()

# %%
data["RestingBP"].hist(edgecolor = "black")
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(4,2, figsize=(16,16))
sns.distplot(data.Age, bins = 20, ax=ax[0,0])  
sns.distplot(data.RestingBP, bins = 20, ax=ax[1,1]) 
sns.distplot(data.Cholesterol, bins = 20, ax=ax[2,0])
sns.distplot(data.FastingBS, bins = 20, ax=ax[2,1])
sns.distplot(data.MaxHR, bins = 20, ax=ax[3,0])
# Out:
# <AxesSubplot:xlabel='MaxHR', ylabel='Density'>

# %%
data.hist(figsize=(10,10),bins=50)
plt.show()

# %%
corr = data.corr()
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['HeartDisease'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('target')
ax[0].set_ylabel('')
sns.countplot('HeartDisease',data=data,ax=ax[1])
ax[1].set_title('HeartDisease')
plt.show()

# %%
sns.set(style="whitegrid")
data.boxplot(figsize=(15,6))
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data)

# %%
sns.pairplot(data,hue='HeartDisease')

# %%
data.corr()
# Out:
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.107589
# Cholesterol      -0.232741
# FastingBS         0.267291
# MaxHR            -0.400421
# Oldpeak           0.403951
# HeartDisease      1.000000

# %%
f, ax = plt.subplots(figsize= [20,15])
sns.heatmap(data.corr(), annot=True, fmt=".2f", ax=ax, cmap = "magma" )
ax.set_title("Correlation Matrix", fontsize=20)
plt.show()

# %%
data.isnull()
# Out:
#        Age    Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  \
# 0    False  False          False      False        False      False
# 1    False  False          False      False        False      False
# 2    False  False          False      False        False      False
# 3    False  False          False      False        False      False
# 4    False  False          False      False        False      False
# ..     ...    ...            ...        ...          ...        ...
# 913  False  False          False      False        False      False
# 914  False  False          False      False        False      False
# 915  False  False          False      False        False      False
# 916  False  False          False      False        False      False
# 917  False  False          False      False        False      False
#
#      RestingECG  MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0         False  False           False    False     False         False
# 1         False  False           False    False     False         False
# 2         False  False           False    False     False         False
# 3         False  False           False    False     False         False
# 4         False  False           False    False     False         False
# ..          ...    ...             ...      ...       ...           ...
# 913       False  False           False    False     False         False
# 914       False  False           False    False     False         False
# 915       False  False           False    False     False         False
# 916       False  False           False    False     False         False
# 917       False  False           False    False     False         False
#
# [918 rows x 12 columns]

# %%
print("# rows in data {0}".format(len(data)))
print("# rows missing RestingBP: {0}".format(len(data.loc[data['RestingBP'] == 0])))
print("# rows missing Cholesterol: {0}".format(len(data.loc[data['Cholesterol'] == 0])))
print("# rows missing FastingBS: {0}".format(len(data.loc[data['FastingBS'] == 0])))
print("# rows missing MaxHR: {0}".format(len(data.loc[data['MaxHR'] == 0])))
print("# rows missing Oldpeak: {0}".format(len(data.loc[data['Oldpeak'] == 0])))
print("# rows missing Age: {0}".format(len(data.loc[data['Age'] == 0])))
# Out:
# # rows in data 918
# # rows missing RestingBP: 1
# # rows missing Cholesterol: 172
# # rows missing FastingBS: 704
# # rows missing MaxHR: 0
# # rows missing Oldpeak: 368
# # rows missing Age: 0

# %%
from sklearn.model_selection import train_test_split

feature_col_names = ['RestingBP', 'Cholesterol', 'FastingBS', 'MaxHR', 'Oldpeak', 'Age']
predicted_class_names = ['HeartDisease']

X = data[feature_col_names].values    
y = data[predicted_class_names].values
split_test_size = 0.30

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=split_test_size, random_state=42)

# %%
trainval = (1.0 * len(X_train)) / (1.0 * len(data.index))
testval = (1.0 * len(X_test)) / (1.0 * len(data.index))
print("{0:0.2f}% in training set".format(trainval * 100))
print("{0:0.2f}% in test set".format(testval * 100))
# Out:
# 69.93% in training set
# 30.07% in test set

# %%
data.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
from sklearn.impute import SimpleImputer
fill_values = SimpleImputer(missing_values=np.nan, strategy='mean')

X_train = fill_values.fit_transform(X_train)
X_test = fill_values.fit_transform(X_test)

# %%
from sklearn.naive_bayes import GaussianNB

nb_model = GaussianNB()

nb_model.fit(X_train, y_train.ravel())
# Out:
# GaussianNB()

# %%
prediction_from_trained_data = nb_model.predict(X_train)

# %%
from sklearn import metrics

accuracy = metrics.accuracy_score(y_train, prediction_from_trained_data)

print ("Accuracy of our naive bayes model is : {0:.4f}".format(accuracy))
# Out:
# Accuracy of our naive bayes model is : 0.7726

# %%
prediction_from_test_data = nb_model.predict(X_test)

accuracy = metrics.accuracy_score(y_test, prediction_from_test_data)

print ("Accuracy of our naive bayes model is: {0:0.4f}".format(accuracy))
# Out:
# Accuracy of our naive bayes model is: 0.7971

# %%
print ("Confusion Matrix")

print ("{0}".format(metrics.confusion_matrix(y_test, prediction_from_test_data, labels=[1, 0])))
# Out:
# Confusion Matrix
# [[130  34]
#  [ 22  90]]

# %%
print ("Classification Report")

print ("{0}".format(metrics.classification_report(y_test, prediction_from_test_data, labels=[1, 0])))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            1       0.86      0.79      0.82       164
#            0       0.73      0.80      0.76       112
#
#     accuracy                           0.80       276
#    macro avg       0.79      0.80      0.79       276
# weighted avg       0.80      0.80      0.80       276

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier(n_estimators=10, criterion='entropy', random_state=1)
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=1)

# %%
model.fit(X_test,y_test)
model.score(X_test,y_test)
# Out:
# 0.9927536231884058

# %%
print ("Confusion Matrix for Random Forest")

print ("{0}".format(metrics.confusion_matrix(y_test, prediction_from_test_data, labels=[1, 0])))

print ("")

print ("Classification Report\n")


print ("{0}".format(metrics.classification_report(y_test, prediction_from_test_data, labels=[1, 0])))
# Out:
# Confusion Matrix for Random Forest
# [[130  34]
#  [ 22  90]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            1       0.86      0.79      0.82       164
#            0       0.73      0.80      0.76       112
#
#     accuracy                           0.80       276
#    macro avg       0.79      0.80      0.79       276
# weighted avg       0.80      0.80      0.80       276

# %%
from sklearn.linear_model import LogisticRegression

lr_model = LogisticRegression(C=0.7, random_state=42)
lr_model.fit(X_train, y_train.ravel())
lr_predict_test = lr_model.predict(X_test)

print ("Accuracy : {0:.4f}".format(metrics.accuracy_score(y_test, lr_predict_test)))

print ("Confusion Matrix")

print (metrics.confusion_matrix(y_test, lr_predict_test, labels=[1, 0]))

print ("")

print ("Classification Report")

print (metrics.classification_report(y_test, lr_predict_test, labels=[1, 0]))
# Out:
# Accuracy : 0.7899
# Confusion Matrix
# [[133  31]
#  [ 27  85]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            1       0.83      0.81      0.82       164
#            0       0.73      0.76      0.75       112
#
#     accuracy                           0.79       276
#    macro avg       0.78      0.78      0.78       276
# weighted avg       0.79      0.79      0.79       276

# %%
from sklearn.linear_model import LogisticRegressionCV

lr_cv_model = LogisticRegressionCV(n_jobs=-1, random_state=42, Cs=3, cv=10, refit=False, class_weight="balanced")  


lr_cv_model.fit(X_train, y_train.ravel())

lr_cv_predict_test = lr_cv_model.predict(X_test)


print( "Accuracy: {0:.4f}".format(metrics.accuracy_score(y_test, lr_cv_predict_test)))
print (metrics.confusion_matrix(y_test, lr_cv_predict_test, labels=[1, 0])) 
print ("")
print ("Classification Report")
print (metrics.classification_report(y_test, lr_cv_predict_test, labels=[1,0]))
# Out:
# Accuracy: 0.7717
# [[125  39]
#  [ 24  88]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            1       0.84      0.76      0.80       164
#            0       0.69      0.79      0.74       112
#
#     accuracy                           0.77       276
#    macro avg       0.77      0.77      0.77       276
# weighted avg       0.78      0.77      0.77       276

# %%
from sklearn.svm import SVC

svm_model = SVC(kernel='linear', C=1, random_state=42)

svm_model.fit(X_train, y_train.ravel())
# Out:
# SVC(C=1, kernel='linear', random_state=42)

# %%
prediction_from_trained_data = svm_model.predict(X_train)

# %%
from sklearn import metrics

accuracy = metrics.accuracy_score(y_train, prediction_from_trained_data)

print ("Accuracy of our SVM model is : {0:.4f}".format(accuracy))
# Out:
# Accuracy of our SVM model is : 0.7695

# %%
svm_predict_test = svm_model.predict(X_test)


svm_accuracy_testdata = metrics.accuracy_score(y_test, svm_predict_test)


print ("Accuracy: {0:.4f}".format(svm_accuracy_testdata))
# Out:
# Accuracy: 0.7754

# %%
print ("Confusion Matrix for Support Vector Machine")


print ("{0}".format(metrics.confusion_matrix(y_test, svm_predict_test, labels=[1, 0])))

print ("")

print ("Classification Report\n")


print ("{0}".format(metrics.classification_report(y_test, svm_predict_test, labels=[1, 0])))
# Out:
# Confusion Matrix for Support Vector Machine
# [[129  35]
#  [ 27  85]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            1       0.83      0.79      0.81       164
#            0       0.71      0.76      0.73       112
#
#     accuracy                           0.78       276
#    macro avg       0.77      0.77      0.77       276
# weighted avg       0.78      0.78      0.78       276

# %%
from sklearn.neural_network import MLPClassifier
ann_model = MLPClassifier(hidden_layer_sizes=(13,13,13),max_iter=500, random_state=42)

ann_model.fit(X_train, y_train.ravel())
# Out:
# MLPClassifier(hidden_layer_sizes=(13, 13, 13), max_iter=500, random_state=42)

# %%
prediction_from_trained_data = ann_model.predict(X_train)

# %%
from sklearn import metrics

accuracy = metrics.accuracy_score(y_train, prediction_from_trained_data)

print ("Accuracy of our ANN model is : {0:.4f}".format(accuracy))
# Out:
# Accuracy of our ANN model is : 0.7726

# %%
ann_predict_test = ann_model.predict(X_test)


ann_accuracy_testdata = metrics.accuracy_score(y_test, ann_predict_test)

print ("Accuracy: {0:.4f}".format(ann_accuracy_testdata))
# Out:
# Accuracy: 0.7500

# %%
print ("Confusion Matrix for Artificial Neural Network")

print ("{0}".format(metrics.confusion_matrix(y_test, ann_predict_test, labels=[1, 0])))

print ("")

print ("Classification Report\n")

print ("{0}".format(metrics.classification_report(y_test, ann_predict_test, labels=[ 1,0])))
# Out:
# Confusion Matrix for Artificial Neural Network
# [[129  35]
#  [ 34  78]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            1       0.79      0.79      0.79       164
#            0       0.69      0.70      0.69       112
#
#     accuracy                           0.75       276
#    macro avg       0.74      0.74      0.74       276
# weighted avg       0.75      0.75      0.75       276

# %%
from sklearn.tree import DecisionTreeClassifier

dt_model = DecisionTreeClassifier(random_state=42)

dt_model.fit(X_train, y_train.ravel())
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
prediction_from_trained_data = dt_model.predict(X_train)

# %%
from sklearn import metrics

accuracy = metrics.accuracy_score(y_train, prediction_from_trained_data)

print ("Accuracy of our DT model is : {0:.4f}".format(accuracy))
# Out:
# Accuracy of our DT model is : 1.0000

# %%
dt_predict_test = dt_model.predict(X_test)

dt_accuracy_testdata = metrics.accuracy_score(y_test, dt_predict_test)


print ("Accuracy: {0:.4f}".format(dt_accuracy_testdata))
# Out:
# Accuracy: 0.6703

# %%
print ("Confusion Matrix for DT")

print ("{0}".format(metrics.confusion_matrix(y_test, dt_predict_test, labels=[1, 0])))

print ("")

print ("Classification Report\n")

print ("{0}".format(metrics.classification_report(y_test, dt_predict_test, labels=[ 1,0])))
# Out:
# Confusion Matrix for DT
# [[111  53]
#  [ 38  74]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            1       0.74      0.68      0.71       164
#            0       0.58      0.66      0.62       112
#
#     accuracy                           0.67       276
#    macro avg       0.66      0.67      0.66       276
# weighted avg       0.68      0.67      0.67       276

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
ac = accuracy_score(y_test, y_pred)

# %%
from sklearn import metrics

accuracy = metrics.accuracy_score(y_train, prediction_from_trained_data)

print ("Accuracy of our ANN model is : {0:.4f}".format(accuracy))
# Out:
# Accuracy of our ANN model is : 1.0000

# %%
dt_predict_test = dt_model.predict(X_test)

dt_accuracy_testdata = metrics.accuracy_score(y_test, dt_predict_test)


print ("Accuracy: {0:.4f}".format(dt_accuracy_testdata))
# Out:
# Accuracy: 0.5870

# %%
print ("Confusion Matrix for DT")

print ("{0}".format(metrics.confusion_matrix(y_test, dt_predict_test, labels=[1, 0])))

print ("")

print ("Classification Report\n")

print ("{0}".format(metrics.classification_report(y_test, dt_predict_test, labels=[ 1,0])))
# Out:
# Confusion Matrix for DT
# [[162   2]
#  [112   0]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            1       0.59      0.99      0.74       164
#            0       0.00      0.00      0.00       112
#
#     accuracy                           0.59       276
#    macro avg       0.30      0.49      0.37       276
# weighted avg       0.35      0.59      0.44       276
